# %% [markdown]
# # 💡 StartupIQ - Phase 5: Business Insights & Decision Simulator Evaluation
#
# This notebook integrates the outcomes of our database queries and machine learning classification to present strategic takeaways for founders and investors.
#
# ## Notebook Structure:
# 1. Overview of critical success and failure factors.
# 2. Model Evaluation (Confusion matrix, ROC-AUC, feature importance layout).
# 3. Simulation of hypothetical cases (Founder Simulator logic verification).
# 4. Final recommendations for operational benchmarks.

# %%
import pandas as pd
import numpy as np
import pickle
import os

# Setup paths
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
MODELS_PATH = os.path.join(PROJECT_ROOT, 'models')

print(f"Models loaded from: {MODELS_PATH}")
