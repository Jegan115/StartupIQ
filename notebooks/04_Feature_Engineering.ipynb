# %% [markdown]
# # ⚙️ StartupIQ - Phase 4: Feature Engineering & Preprocessing
#
# This notebook covers the processing steps required to feed the machine learning model (Founder Decision Simulator). This includes feature extraction, log transformations for skewed variables, category encodings, and scaling.
#
# ## Engineered Features:
# - `cash_runway_months`: Computed ratio of cash reserves vs net monthly burn rate.
# - `funding_velocity`: Total funding raised divided by years since inception.
# - `ltv_cac_ratio`: Core KPI to evaluate customer unit economics.
# - `founder_exits_impact`: Combination indicator of team experience and prior exits.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import os

# Setup paths
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
CLEANED_DATA_PATH = os.path.join(PROJECT_ROOT, 'data', 'cleaned')
FINAL_DATA_PATH = os.path.join(PROJECT_ROOT, 'data', 'final')

print(f"Cleaning features from: {CLEANED_DATA_PATH}")
print(f"Saving features to: {FINAL_DATA_PATH}")
